# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import os
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(10,10)

# %%
dataset = np.load("/home/samuele/Documenti/DeepLearning2016/teopir/ifqi/dataset/blackbox_data/linearmodel/data0.npy")

# %%
df = pd.DataFrame(dataset)

# %%
df.shape
# Out:
# (1214494, 75)

# %%
sns.set()
cr = df.loc[:,0:36].corr()
#df.std()

# %%
ax = sns.heatmap(cr)

# %%
df.loc[0:1000,[5,7]].plot()

# %%
diff_state = dataset[:,0:37] - dataset[:,38:]
diff_state[1000,0:]
# Out:
# array([  0.00000000e+00,  -2.37512589e-03,  -6.86049461e-04,
#         -6.36225915e-01,  -3.74182671e-01,  -1.23662442e+00,
#          1.21675706e+00,  -1.70198369e+00,   4.04009312e-01,
#         -2.03600419e+00,   2.03100622e+00,   0.00000000e+00,
#          2.33471662e-01,   0.00000000e+00,   4.31059734e-02,
#          0.00000000e+00,   1.23326778e-02,   0.00000000e+00,
#          1.09045506e-02,   0.00000000e+00,   7.53188133e-03,
#          0.00000000e+00,   6.15823269e-03,  -4.49347496e-03,
#         -5.38026750e-01,  -2.88628042e-03,  -5.03161550e-02,
#         -2.43943930e-03,  -3.57627869e-06,  -1.20753050e-03,
#         -1.36137009e-04,  -3.16739082e-04,  -3.81469727e-06,
#         -1.35779381e-04,  -1.54554844e-04,   0.00000000e+00,
#          1.00000000e+00])

# %%
df1 = pd.DataFrame(diff_state)
df1.shape
# Out:
# (1214494, 37)

# %%
sns.set()
cr = df1.loc[:,:].corr()

# %%
sns.heatmap(cr)
